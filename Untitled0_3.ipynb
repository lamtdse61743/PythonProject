# %%
import kagglehub
import os
import shutil
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Download the latest version of the dataset
path = kagglehub.dataset_download("jakeshbohaju/brain-tumor")
print("Path to dataset files:", path)

# Define the destination directory in Colab
colab_content_dir = "/content/brain-tumor-dataset"

# Create the destination directory if it doesn’t exist
if not os.path.exists(colab_content_dir):
    os.makedirs(colab_content_dir)

# Move all files from the downloaded path to /content/brain-tumor-dataset
for item in os.listdir(path):
    source = os.path.join(path, item)
    destination = os.path.join(colab_content_dir, item)
    if os.path.isdir(source):
        # If it’s a directory, copy the entire folder
        if os.path.exists(destination):
            shutil.rmtree(destination)  # Remove if it already exists
        shutil.copytree(source, destination)
    else:
        # If it’s a file, copy it
        shutil.copy2(source, destination)
print(f"Moved dataset files to: {colab_content_dir}")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/jakeshbohaju/brain-tumor?dataset_version_number=3...
# 100%|██████████| 14.0M/14.0M [00:00<00:00, 39.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/jakeshbohaju/brain-tumor/versions/3
# Moved dataset files to: /content/brain-tumor-dataset

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Define the specific folder containing the JPG files
image_folder = "/content/brain-tumor-dataset/Brain Tumor/Brain Tumor/"

# Function to load images from the specified folder
def load_images_from_folder(folder_path, num_images_to_load=None):
    images = []
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        if os.path.isfile(img_path) and filename.endswith('.jpg'):  # Targeting JPG files
            # Open and convert image to numpy array
            img = Image.open(img_path).convert('L')  # Grayscale; use 'RGB' for color
            img_array = np.array(img)
            images.append(img_array)
            if num_images_to_load and len(images) >= num_images_to_load:
                break  # Stop loading if we reach the desired number
    return np.array(images)

# Load a few images (e.g., 15) from the folder
num_images_to_show = 15
images = load_images_from_folder(image_folder, num_images_to_load=num_images_to_show)

# Print basic info
print(f"Loaded {len(images)} images")
if images.size > 0:
    print(f"Image shape: {images[0].shape}")

# Display the loaded images
if len(images) > 0:
    plt.figure(figsize=(15, 9))  # Adjust figure size for 3 rows of 5 images
    for i in range(min(num_images_to_show, len(images))):
        row = i // 5  # Integer division to determine row
        col = i % 5   # Modulo to determine column
        plt.subplot(3, 5, i + 1)  # 3 rows, 5 columns
        plt.imshow(images[i], cmap='gray')  # Grayscale display
        plt.title(f"Image {i + 1}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()
else:
    print("No images were loaded. Please check the folder path or file types.")
# Out:
# Loaded 15 images
# Image shape: (240, 240)

# %%
import pandas as pd
df = pd.read_csv("/content/brain-tumor-dataset/Brain Tumor.csv")
df.head()
# Out:
#     Image  Class      Mean     Variance  Standard Deviation   Entropy  \
# 0  Image1      0  6.535339   619.587845           24.891522  0.109059
# 1  Image2      0  8.749969   805.957634           28.389393  0.266538
# 2  Image3      1  7.341095  1143.808219           33.820234  0.001467
# 3  Image4      1  5.958145   959.711985           30.979219  0.001477
# 4  Image5      0  7.315231   729.540579           27.010009  0.146761
#
#    Skewness   Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# 0  4.276477  18.900575   98.613971  0.293314  0.086033     0.530941
# 1  3.718116  14.464618   63.858816  0.475051  0.225674     0.651352
# 2  5.061750  26.479563   81.867206  0.031917  0.001019     0.268275
# 3  5.677977  33.428845  151.229741  0.032024  0.001026     0.243851
# 4  4.283221  19.079108  174.988756  0.343849  0.118232     0.501140
#
#    Dissimilarity  Correlation     Coarseness
# 0       4.473346     0.981939  7.458341e-155
# 1       3.220072     0.988834  7.458341e-155
# 2       5.981800     0.978014  7.458341e-155
# 3       7.700919     0.964189  7.458341e-155
# 4       6.834689     0.972789  7.458341e-155

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    2079
# 1    1683
# Name: count, dtype: int64

# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("/content/brain-tumor-dataset/Brain Tumor.csv")

# Define the folder containing the JPG files
image_folder = "/content/brain-tumor-dataset/Brain Tumor/Brain Tumor/"

# Function to load images and match with CSV
def load_images_with_features(folder_path, dataframe, num_images_to_show=15):
    images = []
    features = []
    for i, filename in enumerate(os.listdir(folder_path)):
        if i >= num_images_to_show:
            break
        img_path = os.path.join(folder_path, filename)
        if os.path.isfile(img_path) and filename.endswith('.jpg'):
            # Load image
            img = Image.open(img_path).convert('L')
            img_array = np.array(img)
            images.append(img_array)
            # Match with CSV (assuming 'Image' column has filenames)
            img_name = filename.split('.')[0]  # Remove .jpg extension
            row = dataframe[dataframe['Image'] == img_name]
            if not row.empty:
                features.append(row.iloc[0])
            else:
                features.append(None)  # If no match found
    return images, features

# Load 15 images and their features
num_images_to_show = 15
images, features = load_images_with_features(image_folder, df, num_images_to_show)

# Display images with features
if images:
    plt.figure(figsize=(15, 9))
    for i in range(min(num_images_to_show, len(images))):
        row = i // 5
        col = i % 5
        plt.subplot(3, 5, i + 1)
        plt.imshow(images[i], cmap='gray')
        # Add title with Class and some features
        if features[i] is not None:
            title = (f"Img {i+1}\nClass: {features[i]['Class']}\n"
                    f"Contrast: {features[i]['Contrast']:.1f}\n"
                    f"Entropy: {features[i]['Entropy']:.2f}")
        else:
            title = f"Img {i+1}\n(No data)"
        plt.title(title)
        plt.axis('off')
    plt.tight_layout()
    plt.show()
else:
    print("No images loaded.")

# %% [markdown]
# # use autoencoder, train model, define anomaly which has RE >75%. Label them 1 (cancer) and 0 (normal). then train a resnet18 on 0 label data then figure out which feature pixel of cancer make them anomaly, then mark them as other colors

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split

# Paths
image_folder = "/content/brain-tumor-dataset/Brain Tumor/Brain Tumor/"
csv_path = "/content/brain-tumor-dataset/Brain Tumor.csv"

# Load CSV
df = pd.read_csv(csv_path)

# Function to load specific images based on filenames from CSV
def load_images_from_folder(folder_path, image_names):
    images = []
    for filename in image_names:
        img_path = os.path.join(folder_path, filename + '.jpg')  # Assuming .jpg extension
        if os.path.isfile(img_path):
            img = Image.open(img_path).convert('L')  # Grayscale
            img = img.resize((128, 128))  # Resize to 128x128
            img_array = np.array(img) / 255.0  # Normalize to [0, 1]
            images.append(img_array)
    return np.array(images)

# Separate Class 0 and Class 1 based on CSV
class_0_df = df[df['Class'] == 0]  # 2079 rows
class_1_df = df[df['Class'] == 1]  # 1683 rows

# Train set: 1500 Class 0
train_df = class_0_df.sample(n=1500, random_state=42)  # Randomly select 1500 Class 0
train_images = load_images_from_folder(image_folder, train_df['Image'])
train_labels = np.zeros(len(train_images))  # All Class 0

# Test set: 579 Class 0 (remaining) + 570 Class 1
remaining_class_0_df = class_0_df.drop(train_df.index)  # 579 remaining Class 0
test_class_0_df = remaining_class_0_df  # All 579
test_class_1_df = class_1_df.sample(n=570, random_state=42)  # 570 Class 1

# Load test images
test_class_0_images = load_images_from_folder(image_folder, test_class_0_df['Image'])
test_class_1_images = load_images_from_folder(image_folder, test_class_1_df['Image'])

# Combine test set
test_images = np.concatenate([test_class_0_images, test_class_1_images])
test_labels = np.concatenate([np.zeros(len(test_class_0_images)), np.ones(len(test_class_1_images))])

# Reshape for model input
train_images = train_images.reshape(-1, 128, 128, 1)
test_images = test_images.reshape(-1, 128, 128, 1)

# Print shapes and label distribution
print(f"Total images loaded: {len(df)}")  # Should be 3762
print(f"Training images (Class 0): {train_images.shape}")
print(f"Testing images (mixed): {test_images.shape}, Labels: {test_labels.shape}")
print("Test label distribution:", np.bincount(test_labels.astype(int)))
# Out:
# Total images loaded: 3762
# Training images (Class 0): (1500, 128, 128, 1)
# Testing images (mixed): (1149, 128, 128, 1), Labels: (1149,)
# Test label distribution: [579 570]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm.keras import TqdmCallback

# Check for GPU availability
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print(f"GPU: {gpu}")
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("No GPU available, running on CPU.")

# Build the autoencoder
input_img = layers.Input(shape=(128, 128, 1))

# Encoder
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# Decoder
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# Autoencoder model
autoencoder = models.Model(input_img, decoded)

# Compile with mixed precision
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Summary
autoencoder.summary()

# Split train_images into training and validation sets (80% train, 20% validation)
train_data, val_data = train_test_split(train_images, test_size=0.2, random_state=42)

# Create tf.data.Dataset for training
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(32).prefetch(tf.data.AUTOTUNE)

# Create tf.data.Dataset for validation
val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_data))
val_dataset = val_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# Train the autoencoder on Class 0 images
with tf.device('/GPU:0'):
    history = autoencoder.fit(train_dataset,
                              epochs=100,
                              validation_data=val_dataset,
                              callbacks=[TqdmCallback(verbose=1)],
                              verbose=0)

# Plot training loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Autoencoder Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict reconstructions for test set
test_predictions = autoencoder.predict(test_images)

# Compute reconstruction errors (MSE per image)
reconstruction_errors = np.mean((test_images - test_predictions) ** 2, axis=(1, 2, 3))

# Separate errors by true class (using test_labels)
class_0_errors = reconstruction_errors[test_labels == 0]  # 579 Class 0
class_1_errors = reconstruction_errors[test_labels == 1]  # 570 Class 1
# Out:
# GPUs available: 1
# GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 128, 128, 1)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 128, 128, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 64, 64, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 32, 32, 16)          │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 64, 64, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 64, 64, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 128, 128, 1)         │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,193 (47.63 KB)
#  Trainable params: 12,193 (47.63 KB)
#  Non-trainable params: 0 (0.00 B)
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step

# %%
# Visualize reconstruction errors distribution
threshold = np.mean(class_0_errors) + 1.5 * np.std(class_0_errors)
plt.figure(figsize=(10, 5))
plt.hist(class_0_errors, bins=50, alpha=0.5, label='Class 0 (Normal)', color='blue')
plt.hist(class_1_errors, bins=50, alpha=0.5, label='Class 1 (Anomaly)', color='red')
plt.axvline(threshold, color='black', linestyle='--', label=f'Threshold = {threshold:.6f}')
plt.title('Reconstruction Error Distribution')
plt.xlabel('Mean Squared Error')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Visualize example reconstructions (first 5 from each class)
num_examples = 5
class_0_indices = np.where(test_labels == 0)[0][:num_examples]
class_1_indices = np.where(test_labels == 1)[0][:num_examples]

plt.figure(figsize=(15, 6))
for i, idx in enumerate(np.concatenate([class_0_indices, class_1_indices])):
    plt.subplot(2, num_examples * 2, i + 1)
    plt.imshow(test_images[idx].reshape(128, 128), cmap='gray')
    plt.title(f"Original\nClass {int(test_labels[idx])}")
    plt.axis('off')

    plt.subplot(2, num_examples * 2, i + 1 + num_examples * 2)
    plt.imshow(test_predictions[idx].reshape(128, 128), cmap='gray')
    plt.title(f"Reconstructed\nError: {reconstruction_errors[idx]:.6f}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Reconstruct test images
reconstructed_images = autoencoder.predict(test_images)

# Compute reconstruction error (MSE) for each image
mse = np.mean(np.square(test_images - reconstructed_images), axis=(1, 2, 3))

# Set a threshold for anomaly detection (e.g., 95th percentile of training error)
train_reconstructed = autoencoder.predict(train_images)
train_mse = np.mean(np.square(train_images - train_reconstructed), axis=(1, 2, 3))
threshold = np.percentile(train_mse, 1)  # Adjust percentile as needed
print(f"Anomaly detection threshold: {threshold}")

# Classify test images as normal (0) or anomalous (1) based on threshold
predictions = (mse > threshold).astype(int)

# Evaluate performance
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy = accuracy_score(test_labels, predictions)
conf_matrix = confusion_matrix(test_labels, predictions)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)

# Visualize some test images with their reconstruction and errors
num_samples = 5
plt.figure(figsize=(15, 6))
for i in range(num_samples):
    # Original image
    plt.subplot(3, num_samples, i + 1)
    plt.imshow(test_images[i].reshape(128, 128), cmap='gray')
    plt.title(f"Label: {int(test_labels[i])}")
    plt.axis('off')

    # Reconstructed image
    plt.subplot(3, num_samples, i + 1 + num_samples)
    plt.imshow(reconstructed_images[i].reshape(128, 128), cmap='gray')
    plt.title(f"MSE: {mse[i]:.4f}")
    plt.axis('off')

    # Difference
    plt.subplot(3, num_samples, i + 1 + 2 * num_samples)
    plt.imshow(np.abs(test_images[i] - reconstructed_images[i]).reshape(128, 128), cmap='gray')
    plt.title(f"Pred: {predictions[i]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Anomaly detection threshold: 0.00031407952846514067
# Accuracy: 0.4995648389904265
# Confusion Matrix:
# [[ 10 569]
#  [  6 564]]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For a nicer heatmap visualization

# Set threshold based on Class 0 errors (mean + 2 standard deviations)
threshold = np.mean(class_0_errors) + 2 * np.std(class_0_errors)
print(f"Reconstruction error threshold: {threshold:.6f}")

# Classify test images based on threshold
predicted_labels = (reconstruction_errors > threshold).astype(int)

# Calculate accuracy and confusion matrix
accuracy = np.mean(predicted_labels == test_labels)
print(f"Detection accuracy: {accuracy:.4f}")

# Confusion matrix
conf_matrix = tf.math.confusion_matrix(test_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix.numpy(), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Class 0', 'Predicted Class 1'],
            yticklabels=['True Class 0', 'True Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Reconstruction error threshold: 0.001484
# Detection accuracy: 0.4978
# Confusion Matrix:
# tf.Tensor(
# [[564  15]
#  [562   8]], shape=(2, 2), dtype=int32)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For a nicer heatmap visualization

# Set threshold based on Class 0 errors (mean + 2 standard deviations)
threshold = np.mean(class_0_errors) + 1.5 * np.std(class_0_errors)
print(f"Reconstruction error threshold: {threshold:.6f}")

# Classify test images based on threshold
predicted_labels = (reconstruction_errors > threshold).astype(int)

# Calculate accuracy and confusion matrix
accuracy = np.mean(predicted_labels == test_labels)
print(f"Detection accuracy: {accuracy:.4f}")

# Confusion matrix
conf_matrix = tf.math.confusion_matrix(test_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix.numpy(), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Class 0', 'Predicted Class 1'],
            yticklabels=['True Class 0', 'True Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Reconstruction error threshold: 0.001307
# Detection accuracy: 0.4848
# Confusion Matrix:
# tf.Tensor(
# [[536  43]
#  [549  21]], shape=(2, 2), dtype=int32)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tqdm.keras import TqdmCallback

# Check GPU availability
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print(f"GPU: {gpu}")
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("No GPU available, running on CPU.")

# Custom VAE layer for sampling from latent space
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim), dtype=tf.float16)
        return z_mean + tf.cast(tf.exp(tf.cast(0.5 * z_log_var, tf.float16)), tf.float16) * epsilon

# VAE parameters
latent_dim = 32
input_shape = (128, 128, 1)

# Encoder
inputs = layers.Input(shape=input_shape)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Flatten()(x)
z_mean = layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
z = Sampling()([z_mean, z_log_var])
encoder = models.Model(inputs, [z_mean, z_log_var, z], name='encoder')

# Decoder
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(16 * 16 * 128)(latent_inputs)
x = layers.Reshape((16, 16, 128))(x)
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
outputs = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
decoder = models.Model(latent_inputs, outputs, name='decoder')

# VAE model
class VAE(models.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    def call(self, inputs, training=None):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)
        return reconstruction

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def train_step(self, data):
        if isinstance(data, tuple):
            x = data[0]
        else:
            x = data
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(x)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.keras.losses.binary_crossentropy(x, reconstruction), axis=[1, 2]))
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            x = data[0]
        else:
            x = data
        z_mean, z_log_var, z = self.encoder(x)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.keras.losses.binary_crossentropy(x, reconstruction), axis=[1, 2]))
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + kl_loss
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# Instantiate and compile VAE (no loss specified, handled in train_step)
vae = VAE(encoder, decoder)
vae.compile(optimizer='adam')  # Loss is computed in train_step/test_step

# Use mixed precision
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# Split train_images into training and validation
train_data, val_data = train_test_split(train_images, test_size=0.2, random_state=42)

# Create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data)).shuffle(1024).batch(32).prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_data)).batch(32).prefetch(tf.data.AUTOTUNE)

# Train the VAE on Class 0
with tf.device('/GPU:0'):
    history = vae.fit(train_dataset,
                      epochs=50,
                      validation_data=val_dataset,
                      callbacks=[TqdmCallback(verbose=1)],
                      verbose=0)

# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('VAE Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict reconstructions for test set
_, _, z = encoder.predict(test_images)
test_predictions = decoder.predict(z)

# Compute reconstruction errors
reconstruction_errors = np.mean((test_images - test_predictions) ** 2, axis=(1, 2, 3))

# Separate errors by class
class_0_errors = reconstruction_errors[test_labels == 0]  # 579
class_1_errors = reconstruction_errors[test_labels == 1]  # 570

# Set threshold
threshold = np.mean(class_0_errors) + 2 * np.std(class_0_errors)
print(f"Reconstruction error threshold: {threshold:.6f}")

# Classify
predicted_labels = (reconstruction_errors > threshold).astype(int)

# Accuracy and confusion matrix
accuracy = np.mean(predicted_labels == test_labels)
print(f"Detection accuracy: {accuracy:.4f}")

conf_matrix = tf.math.confusion_matrix(test_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix.numpy(), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Class 0', 'Predicted Class 1'],
            yticklabels=['True Class 0', 'True Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# GPUs available: 1
# GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# Reconstruction error threshold: 0.006246
# Detection accuracy: 0.7372
# Confusion Matrix:
# tf.Tensor(
# [[554  25]
#  [277 293]], shape=(2, 2), dtype=int32)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tqdm.keras import TqdmCallback

# Check GPU availability
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print(f"GPU: {gpu}")
        tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("No GPU available, running on CPU.")

# Custom VAE layer for sampling
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim), dtype=tf.float16)
        return z_mean + tf.cast(tf.exp(tf.cast(0.5 * z_log_var, tf.float16)), tf.float16) * epsilon

# VAE parameters
latent_dim = 64  # Increased latent space size
input_shape = (128, 128, 1)

# Encoder (deeper)
inputs = layers.Input(shape=input_shape)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)  # Added layer
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Flatten()(x)
z_mean = layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
z = Sampling()([z_mean, z_log_var])
encoder = models.Model(inputs, [z_mean, z_log_var, z], name='encoder')

# Decoder (deeper)
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(8 * 8 * 256)(latent_inputs)  # Adjusted for deeper encoder
x = layers.Reshape((8, 8, 256))(x)
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
outputs = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
decoder = models.Model(latent_inputs, outputs, name='decoder')

# VAE model
class VAE(models.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    def call(self, inputs, training=None):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)
        return reconstruction

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def train_step(self, data):
        if isinstance(data, tuple):
            x = data[0]
        else:
            x = data
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(x)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.keras.losses.binary_crossentropy(x, reconstruction), axis=[1, 2]))
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + 0.1 * kl_loss  # Reduced KL weight
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            x = data[0]
        else:
            x = data
        z_mean, z_log_var, z = self.encoder(x)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tf.keras.losses.binary_crossentropy(x, reconstruction), axis=[1, 2]))
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + 0.1 * kl_loss
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# Instantiate and compile VAE
vae = VAE(encoder, decoder)
vae.compile(optimizer='adam')

# Use mixed precision
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# Split train_images into training and validation
train_data, val_data = train_test_split(train_images, test_size=0.2, random_state=42)

# Create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data)).shuffle(1024).batch(32).prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_data)).batch(32).prefetch(tf.data.AUTOTUNE)

# Train the VAE on Class 0
with tf.device('/GPU:0'):
    history = vae.fit(train_dataset,
                      epochs=100,  # Increased epochs
                      validation_data=val_dataset,
                      callbacks=[TqdmCallback(verbose=1)],
                      verbose=0)

# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('VAE Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict reconstructions for test set
_, _, z = encoder.predict(test_images)
test_predictions = decoder.predict(z)

# Compute reconstruction errors
reconstruction_errors = np.mean((test_images - test_predictions) ** 2, axis=(1, 2, 3))

# Separate errors by class
class_0_errors = reconstruction_errors[test_labels == 0]  # 579
class_1_errors = reconstruction_errors[test_labels == 1]  # 570

# Set threshold (tighter)
threshold = np.mean(class_0_errors) + 1.5 * np.std(class_0_errors)  # Adjusted to 1.5*std
print(f"Reconstruction error threshold: {threshold:.6f}")

# Classify
predicted_labels = (reconstruction_errors > threshold).astype(int)

# Accuracy and confusion matrix
accuracy = np.mean(predicted_labels == test_labels)
print(f"Detection accuracy: {accuracy:.4f}")

conf_matrix = tf.math.confusion_matrix(test_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix.numpy(), annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Class 0', 'Predicted Class 1'],
            yticklabels=['True Class 0', 'True Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot error distribution for insight
plt.figure(figsize=(10, 5))
plt.hist(class_0_errors, bins=50, alpha=0.5, label='Class 0', color='blue')
plt.hist(class_1_errors, bins=50, alpha=0.5, label='Class 1', color='red')
plt.axvline(threshold, color='black', linestyle='--', label=f'Threshold = {threshold:.6f}')
plt.title('Reconstruction Error Distribution')
plt.xlabel('Mean Squared Error')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# GPUs available: 1
# GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step
# Reconstruction error threshold: 0.005069
# Detection accuracy: 0.7728
# Confusion Matrix:
# tf.Tensor(
# [[533  46]
#  [215 355]], shape=(2, 2), dtype=int32)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix

# Reconstruct test images using VAE's encoder and decoder
_, _, z = encoder.predict(test_images)  # Get latent representation
reconstructed_images = decoder.predict(z)  # Decode to reconstructions

# Compute reconstruction error (MSE) for each image
mse = np.mean(np.square(test_images - reconstructed_images), axis=(1, 2, 3))

# Set a threshold for anomaly detection (e.g., 95th percentile of training error)
_, _, train_z = encoder.predict(train_images)  # Encode training data
train_reconstructed = decoder.predict(train_z)  # Decode training reconstructions
train_mse = np.mean(np.square(train_images - train_reconstructed), axis=(1, 2, 3))
threshold = np.percentile(train_mse, 95)  # 95th percentile of Class 0 errors
print(f"Anomaly detection threshold: {threshold:.6f}")

# Classify test images as normal (0) or anomalous (1) based on threshold
predictions = (mse > threshold).astype(int)

# Evaluate performance
accuracy = accuracy_score(test_labels, predictions)
conf_matrix = confusion_matrix(test_labels, predictions)

print(f"Accuracy: {accuracy:.4f}")
print("Confusion Matrix:")
print(conf_matrix)

# Visualize example reconstructions (first 5 from each class)
num_examples = 5
class_0_indices = np.where(test_labels == 0)[0][:num_examples]
class_1_indices = np.where(test_labels == 1)[0][:num_examples]

plt.figure(figsize=(15, 6))
for i, idx in enumerate(np.concatenate([class_0_indices, class_1_indices])):
    plt.subplot(2, num_examples * 2, i + 1)
    plt.imshow(test_images[idx].reshape(128, 128), cmap='gray')
    plt.title(f"Original\nClass {int(test_labels[idx])}")
    plt.axis('off')

    plt.subplot(2, num_examples * 2, i + 1 + num_examples * 2)
    plt.imshow(reconstructed_images[idx].reshape(128, 128), cmap='gray')
    plt.title(f"Reconstructed\nError: {mse[idx]:.6f}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# Visualize some test images with their reconstruction and differences (first 5 test images)
num_samples = 5
plt.figure(figsize=(15, 6))
for i in range(num_samples):
    # Original image
    plt.subplot(3, num_samples, i + 1)
    plt.imshow(test_images[i].reshape(128, 128), cmap='gray')
    plt.title(f"Label: {int(test_labels[i])}")
    plt.axis('off')

    # Reconstructed image
    plt.subplot(3, num_samples, i + 1 + num_samples)
    plt.imshow(reconstructed_images[i].reshape(128, 128), cmap='gray')
    plt.title(f"MSE: {mse[i]:.6f}")
    plt.axis('off')

    # Difference
    plt.subplot(3, num_samples, i + 1 + 2 * num_samples)
    plt.imshow(np.abs(test_images[i] - reconstructed_images[i]).reshape(128, 128), cmap='gray')
    plt.title(f"Pred: {predictions[i]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Anomaly detection threshold: 0.004198
# Accuracy: 0.8042
# Confusion Matrix:
# [[486  93]
#  [132 438]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from tqdm import tqdm  # Import tqdm for progress tracking

# Reconstruct test images using VAE's encoder and decoder
_, _, z = encoder.predict(test_images)  # Get latent representation
reconstructed_images = decoder.predict(z)  # Decode to reconstructions

# Compute reconstruction error (MSE) for each image
mse = np.mean(np.square(test_images - reconstructed_images), axis=(1, 2, 3))

# Compute training MSE for threshold calculation
_, _, train_z = encoder.predict(train_images)  # Encode training data
train_reconstructed = decoder.predict(train_z)  # Decode training reconstructions
train_mse = np.mean(np.square(train_images - train_reconstructed), axis=(1, 2, 3))

# Dictionary to store threshold and accuracy results
results = {}

# Iterate over percentiles from 1 to 100 with tqdm
for i in tqdm(range(100), desc="Evaluating Thresholds"):  # Add tqdm with a description
    percentile = 1 + i  # 1% to 100%
    threshold = np.percentile(train_mse, percentile)  # Percentile of Class 0 errors
    print(f"Anomaly detection threshold: {threshold:.6f}")

    # Classify test images as normal (0) or anomalous (1) based on threshold
    predictions = (mse > threshold).astype(int)

    # Evaluate performance
    accuracy = accuracy_score(test_labels, predictions)
    conf_matrix = confusion_matrix(test_labels, predictions)

    # Store results
    results[percentile] = {
        'threshold': threshold,
        'accuracy': accuracy,
        'conf_matrix': conf_matrix,
        'predictions': predictions  # Store predictions for the best result
    }

    print(f"Threshold: {percentile}%")
    print(f"Accuracy: {accuracy:.4f}")
    print("Confusion Matrix:")
    print(conf_matrix)

# After all iterations, print all results and find the best one
print("\n=== All Results ===")
best_percentile = None
best_accuracy = -1
for percentile, result in results.items():
    print(f"Percentile: {percentile}%")
    print(f"Threshold: {result['threshold']:.6f}")
    print(f"Accuracy: {result['accuracy']:.4f}")
    print(f"Confusion Matrix:\n{result['conf_matrix']}")
    print("-------------------")
    if result['accuracy'] > best_accuracy:
        best_accuracy = result['accuracy']
        best_percentile = percentile

print("\n=== Best Result ===")
print(f"Best Percentile: {best_percentile}%")
print(f"Threshold: {results[best_percentile]['threshold']:.6f}")
print(f"Accuracy: {results[best_percentile]['accuracy']:.4f}")
print(f"Confusion Matrix:\n{results[best_percentile]['conf_matrix']}")

# Plot threshold vs accuracy
thresholds = [results[p]['threshold'] for p in results]
accuracies = [results[p]['accuracy'] for p in results]

plt.figure(figsize=(10, 6))
plt.plot(thresholds, accuracies, marker='o', linestyle='-', color='b')
plt.title('Threshold vs Accuracy')
plt.xlabel('Reconstruction Error Threshold')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Evaluating Thresholds:  28%|██▊       | 28/100 [00:00<00:00, 264.42it/s]
# Anomaly detection threshold: 0.000555
# Threshold: 1%
# Accuracy: 0.4970
# Confusion Matrix:
# [[  1 578]
#  [  0 570]]
# Anomaly detection threshold: 0.000674
# Threshold: 2%
# Accuracy: 0.4996
# Confusion Matrix:
# [[  4 575]
#  [  0 570]]
# Anomaly detection threshold: 0.000771
# Threshold: 3%
# Accuracy: 0.5022
# Confusion Matrix:
# [[  7 572]
#  [  0 570]]
# Anomaly detection threshold: 0.000825
# Threshold: 4%
# Accuracy: 0.5048
# Confusion Matrix:
# [[ 10 569]
#  [  0 570]]
# Anomaly detection threshold: 0.000875
# Threshold: 5%
# Accuracy: 0.5065
# Confusion Matrix:
# [[ 12 567]
#  [  0 570]]
# Anomaly detection threshold: 0.000929
# Threshold: 6%
# Accuracy: 0.5091
# Confusion Matrix:
# [[ 15 564]
#  [  0 570]]
# Anomaly detection threshold: 0.000963
# Threshold: 7%
# Accuracy: 0.5091
# Confusion Matrix:
# [[ 15 564]
#  [  0 570]]
# Anomaly detection threshold: 0.000997
# Threshold: 8%
# Accuracy: 0.5100
# Confusion Matrix:
# [[ 16 563]
#  [  0 570]]
# Anomaly detection threshold: 0.001022
# Threshold: 9%
# Accuracy: 0.5109
# Confusion Matrix:
# [[ 17 562]
#  [  0 570]]
# Anomaly detection threshold: 0.001048
# Threshold: 10%
# Accuracy: 0.5126
# Confusion Matrix:
# [[ 20 559]
#  [  1 569]]
# Anomaly detection threshold: 0.001072
# Threshold: 11%
# Accuracy: 0.5135
# Confusion Matrix:
# [[ 21 558]
#  [  1 569]]
# Anomaly detection threshold: 0.001111
# Threshold: 12%
# Accuracy: 0.5144
# Confusion Matrix:
# [[ 22 557]
#  [  1 569]]
# Anomaly detection threshold: 0.001169
# Threshold: 13%
# Accuracy: 0.5187
# Confusion Matrix:
# [[ 27 552]
#  [  1 569]]
# Anomaly detection threshold: 0.001192
# Threshold: 14%
# Accuracy: 0.5196
# Confusion Matrix:
# [[ 28 551]
#  [  1 569]]
# Anomaly detection threshold: 0.001211
# Threshold: 15%
# Accuracy: 0.5213
# Confusion Matrix:
# [[ 30 549]
#  [  1 569]]
# Anomaly detection threshold: 0.001247
# Threshold: 16%
# Accuracy: 0.5257
# Confusion Matrix:
# [[ 35 544]
#  [  1 569]]
# Anomaly detection threshold: 0.001275
# Threshold: 17%
# Accuracy: 0.5274
# Confusion Matrix:
# [[ 37 542]
#  [  1 569]]
# Anomaly detection threshold: 0.001298
# Threshold: 18%
# Accuracy: 0.5309
# Confusion Matrix:
# [[ 41 538]
#  [  1 569]]
# Anomaly detection threshold: 0.001319
# Threshold: 19%
# Accuracy: 0.5335
# Confusion Matrix:
# [[ 44 535]
#  [  1 569]]
# Anomaly detection threshold: 0.001345
# Threshold: 20%
# Accuracy: 0.5335
# Confusion Matrix:
# [[ 44 535]
#  [  1 569]]
# Anomaly detection threshold: 0.001365
# Threshold: 21%
# Accuracy: 0.5335
# Confusion Matrix:
# [[ 44 535]
#  [  1 569]]
# Anomaly detection threshold: 0.001387
# Threshold: 22%
# Accuracy: 0.5344
# Confusion Matrix:
# [[ 45 534]
#  [  1 569]]
# Anomaly detection threshold: 0.001413
# Threshold: 23%
# Accuracy: 0.5396
# Confusion Matrix:
# [[ 51 528]
#  [  1 569]]
# Anomaly detection threshold: 0.001434
# Threshold: 24%
# Accuracy: 0.5422
# Confusion Matrix:
# [[ 54 525]
#  [  1 569]]
# Anomaly detection threshold: 0.001457
# Threshold: 25%
# Accuracy: 0.5448
# Confusion Matrix:
# [[ 57 522]
#  [  1 569]]
# Anomaly detection threshold: 0.001477
# Threshold: 26%
# Accuracy: 0.5492
# Confusion Matrix:
# [[ 62 517]
#  [  1 569]]
# Anomaly detection threshold: 0.001497
# Threshold: 27%
# Accuracy: 0.5527
# Confusion Matrix:
# [[ 66 513]
#  [  1 569]]
# Anomaly detection threshold: 0.001514
# Threshold: 28%
# Accuracy: 0.5535
# Confusion Matrix:
# [[ 67 512]
#  [  1 569]]
# Anomaly detection threshold: 0.001534
# Threshold: 29%
# Accuracy: 0.5544
# Confusion Matrix:
# [[ 68 511]
#  [  1 569]]
# Anomaly detection threshold: 0.001562
# Threshold: 30%
# Accuracy: 0.5570
# Confusion Matrix:
# [[ 71 508]
#  [  1 569]]
# Anomaly detection threshold: 0.001584
# Threshold: 31%
# Accuracy: 0.5579
# Confusion Matrix:
# [[ 72 507]
#  [  1 569]]
# Anomaly detection threshold: 0.001609
# Threshold: 32%
# Accuracy: 0.5605
# Confusion Matrix:
# [[ 75 504]
#  [  1 569]]
# Anomaly detection threshold: 0.001639
# Threshold: 33%
# Accuracy: 0.5648
# Confusion Matrix:
# [[ 80 499]
#  [  1 569]]
# Anomaly detection threshold: 0.001668
# Threshold: 34%
# Accuracy: 0.5674
# Confusion Matrix:
# [[ 83 496]
#  [  1 569]]
# Anomaly detection threshold: 0.001687
# Threshold: 35%
# Accuracy: 0.5692
# Confusion Matrix:
# [[ 85 494]
#  [  1 569]]
# Anomaly detection threshold: 0.001704
# Threshold: 36%
# Accuracy: 0.5718
# Confusion Matrix:
# [[ 88 491]
#  [  1 569]]
# Anomaly detection threshold: 0.001720
# Threshold: 37%
# Accuracy: 0.5727
# Confusion Matrix:
# [[ 90 489]
#  [  2 568]]
# Anomaly detection threshold: 0.001749
# Threshold: 38%
# Accuracy: 0.5735
# Confusion Matrix:
# [[ 91 488]
#  [  2 568]]
# Anomaly detection threshold: 0.001764
# Threshold: 39%
# Accuracy: 0.5753
# Confusion Matrix:
# [[ 93 486]
#  [  2 568]]
# Anomaly detection threshold: 0.001786
# Threshold: 40%
# Accuracy: 0.5770
# Confusion Matrix:
# [[ 96 483]
#  [  3 567]]
# Anomaly detection threshold: 0.001809
# Threshold: 41%
# Accuracy: 0.5805
# Confusion Matrix:
# [[100 479]
#  [  3 567]]
# Anomaly detection threshold: 0.001836
# Threshold: 42%
# Accuracy: 0.5849
# Confusion Matrix:
# [[106 473]
#  [  4 566]]
# Anomaly detection threshold: 0.001871
# Threshold: 43%
# Accuracy: 0.5936
# Confusion Matrix:
# [[116 463]
#  [  4 566]]
# Anomaly detection threshold: 0.001884
# Threshold: 44%
# Accuracy: 0.5953
# Confusion Matrix:
# [[118 461]
#  [  4 566]]
# Anomaly detection threshold: 0.001904
# Threshold: 45%
# Accuracy: 0.5970
# Confusion Matrix:
# [[120 459]
#  [  4 566]]
# Anomaly detection threshold: 0.001916
# Threshold: 46%
# Accuracy: 0.5979
# Confusion Matrix:
# [[121 458]
#  [  4 566]]
# Anomaly detection threshold: 0.001932
# Threshold: 47%
# Accuracy: 0.6023
# Confusion Matrix:
# [[126 453]
#  [  4 566]]
# Anomaly detection threshold: 0.001951
# Threshold: 48%
# Accuracy: 0.6066
# Confusion Matrix:
# [[132 447]
#  [  5 565]]
# Anomaly detection threshold: 0.001972
# Threshold: 49%
# Accuracy: 0.6101
# Confusion Matrix:
# [[137 442]
#  [  6 564]]
# Anomaly detection threshold: 0.001995
# Threshold: 50%
# Accuracy: 0.6136
# Confusion Matrix:
# [[141 438]
#  [  6 564]]
# Evaluating Thresholds:  80%|████████  | 80/100 [00:00<00:00, 189.36it/s]
# Anomaly detection threshold: 0.002012
# Threshold: 51%
# Accuracy: 0.6171
# Confusion Matrix:
# [[145 434]
#  [  6 564]]
# Anomaly detection threshold: 0.002031
# Threshold: 52%
# Accuracy: 0.6214
# Confusion Matrix:
# [[150 429]
#  [  6 564]]
# Anomaly detection threshold: 0.002051
# Threshold: 53%
# Accuracy: 0.6214
# Confusion Matrix:
# [[151 428]
#  [  7 563]]
# Anomaly detection threshold: 0.002070
# Threshold: 54%
# Accuracy: 0.6258
# Confusion Matrix:
# [[156 423]
#  [  7 563]]
# Anomaly detection threshold: 0.002080
# Threshold: 55%
# Accuracy: 0.6292
# Confusion Matrix:
# [[160 419]
#  [  7 563]]
# Anomaly detection threshold: 0.002112
# Threshold: 56%
# Accuracy: 0.6336
# Confusion Matrix:
# [[166 413]
#  [  8 562]]
# Anomaly detection threshold: 0.002136
# Threshold: 57%
# Accuracy: 0.6388
# Confusion Matrix:
# [[172 407]
#  [  8 562]]
# Anomaly detection threshold: 0.002171
# Threshold: 58%
# Accuracy: 0.6432
# Confusion Matrix:
# [[178 401]
#  [  9 561]]
# Anomaly detection threshold: 0.002195
# Threshold: 59%
# Accuracy: 0.6466
# Confusion Matrix:
# [[182 397]
#  [  9 561]]
# Anomaly detection threshold: 0.002231
# Threshold: 60%
# Accuracy: 0.6571
# Confusion Matrix:
# [[195 384]
#  [ 10 560]]
# Anomaly detection threshold: 0.002249
# Threshold: 61%
# Accuracy: 0.6580
# Confusion Matrix:
# [[196 383]
#  [ 10 560]]
# Anomaly detection threshold: 0.002284
# Threshold: 62%
# Accuracy: 0.6641
# Confusion Matrix:
# [[205 374]
#  [ 12 558]]
# Anomaly detection threshold: 0.002302
# Threshold: 63%
# Accuracy: 0.6675
# Confusion Matrix:
# [[210 369]
#  [ 13 557]]
# Anomaly detection threshold: 0.002336
# Threshold: 64%
# Accuracy: 0.6710
# Confusion Matrix:
# [[216 363]
#  [ 15 555]]
# Anomaly detection threshold: 0.002352
# Threshold: 65%
# Accuracy: 0.6736
# Confusion Matrix:
# [[220 359]
#  [ 16 554]]
# Anomaly detection threshold: 0.002381
# Threshold: 66%
# Accuracy: 0.6832
# Confusion Matrix:
# [[232 347]
#  [ 17 553]]
# Anomaly detection threshold: 0.002405
# Threshold: 67%
# Accuracy: 0.6910
# Confusion Matrix:
# [[241 338]
#  [ 17 553]]
# Anomaly detection threshold: 0.002416
# Threshold: 68%
# Accuracy: 0.6919
# Confusion Matrix:
# [[242 337]
#  [ 17 553]]
# Anomaly detection threshold: 0.002433
# Threshold: 69%
# Accuracy: 0.6945
# Confusion Matrix:
# [[245 334]
#  [ 17 553]]
# Anomaly detection threshold: 0.002477
# Threshold: 70%
# Accuracy: 0.7058
# Confusion Matrix:
# [[260 319]
#  [ 19 551]]
# Anomaly detection threshold: 0.002498
# Threshold: 71%
# Accuracy: 0.7058
# Confusion Matrix:
# [[261 318]
#  [ 20 550]]
# Anomaly detection threshold: 0.002514
# Threshold: 72%
# Accuracy: 0.7058
# Confusion Matrix:
# [[261 318]
#  [ 20 550]]
# Anomaly detection threshold: 0.002557
# Threshold: 73%
# Accuracy: 0.7180
# Confusion Matrix:
# [[277 302]
#  [ 22 548]]
# Anomaly detection threshold: 0.002591
# Threshold: 74%
# Accuracy: 0.7258
# Confusion Matrix:
# [[289 290]
#  [ 25 545]]
# Anomaly detection threshold: 0.002618
# Threshold: 75%
# Accuracy: 0.7285
# Confusion Matrix:
# [[294 285]
#  [ 27 543]]
# Anomaly detection threshold: 0.002660
# Threshold: 76%
# Accuracy: 0.7328
# Confusion Matrix:
# [[300 279]
#  [ 28 542]]
# Anomaly detection threshold: 0.002703
# Threshold: 77%
# Accuracy: 0.7302
# Confusion Matrix:
# [[302 277]
#  [ 33 537]]
# Anomaly detection threshold: 0.002746
# Threshold: 78%
# Accuracy: 0.7346
# Confusion Matrix:
# [[311 268]
#  [ 37 533]]
# Anomaly detection threshold: 0.002788
# Threshold: 79%
# Accuracy: 0.7398
# Confusion Matrix:
# [[319 260]
#  [ 39 531]]
# Anomaly detection threshold: 0.002825
# Threshold: 80%
# Accuracy: 0.7459
# Confusion Matrix:
# [[326 253]
#  [ 39 531]]
# Anomaly detection threshold: 0.002867
# Threshold: 81%
# Accuracy: 0.7520
# Confusion Matrix:
# [[335 244]
#  [ 41 529]]
# Anomaly detection threshold: 0.002903
# Threshold: 82%
# Accuracy: 0.7572
# Confusion Matrix:
# [[342 237]
#  [ 42 528]]
# Anomaly detection threshold: 0.002949
# Evaluating Thresholds: 100%|██████████| 100/100 [00:00<00:00, 175.09it/s]
# Threshold: 83%
# Accuracy: 0.7607
# Confusion Matrix:
# [[347 232]
#  [ 43 527]]
# Anomaly detection threshold: 0.003029
# Threshold: 84%
# Accuracy: 0.7624
# Confusion Matrix:
# [[358 221]
#  [ 52 518]]
# Anomaly detection threshold: 0.003060
# Threshold: 85%
# Accuracy: 0.7624
# Confusion Matrix:
# [[361 218]
#  [ 55 515]]
# Anomaly detection threshold: 0.003130
# Threshold: 86%
# Accuracy: 0.7641
# Confusion Matrix:
# [[369 210]
#  [ 61 509]]
# Anomaly detection threshold: 0.003193
# Threshold: 87%
# Accuracy: 0.7685
# Confusion Matrix:
# [[377 202]
#  [ 64 506]]
# Anomaly detection threshold: 0.003261
# Threshold: 88%
# Accuracy: 0.7702
# Confusion Matrix:
# [[383 196]
#  [ 68 502]]
# Anomaly detection threshold: 0.003371
# Threshold: 89%
# Accuracy: 0.7842
# Confusion Matrix:
# [[403 176]
#  [ 72 498]]
# Anomaly detection threshold: 0.003482
# Threshold: 90%
# Accuracy: 0.7876
# Confusion Matrix:
# [[424 155]
#  [ 89 481]]
# Anomaly detection threshold: 0.003573
# Threshold: 91%
# Accuracy: 0.7929
# Confusion Matrix:
# [[434 145]
#  [ 93 477]]
# Anomaly detection threshold: 0.003661
# Threshold: 92%
# Accuracy: 0.7955
# Confusion Matrix:
# [[444 135]
#  [100 470]]
# Anomaly detection threshold: 0.003862
# Threshold: 93%
# Accuracy: 0.7937
# Confusion Matrix:
# [[454 125]
#  [112 458]]
# Anomaly detection threshold: 0.004115
# Threshold: 94%
# Accuracy: 0.7903
# Confusion Matrix:
# [[475 104]
#  [137 433]]
# Anomaly detection threshold: 0.004300
# Threshold: 95%
# Accuracy: 0.7894
# Confusion Matrix:
# [[487  92]
#  [150 420]]
# Anomaly detection threshold: 0.004623
# Threshold: 96%
# Accuracy: 0.7876
# Confusion Matrix:
# [[511  68]
#  [176 394]]
# Anomaly detection threshold: 0.004917
# Threshold: 97%
# Accuracy: 0.7824
# Confusion Matrix:
# [[527  52]
#  [198 372]]
# Anomaly detection threshold: 0.005752
# Threshold: 98%
# Accuracy: 0.7293
# Confusion Matrix:
# [[552  27]
#  [284 286]]
# Anomaly detection threshold: 0.006466
# Threshold: 99%
# Accuracy: 0.6849
# Confusion Matrix:
# [[563  16]
#  [346 224]]
# Anomaly detection threshold: 0.013164
# Threshold: 100%
# Accuracy: 0.5117
# Confusion Matrix:
# [[579   0]
#  [561   9]]
#
# === All Results ===
# Percentile: 1%
# Threshold: 0.000555
# Accuracy: 0.4970
# Confusion Matrix:
# [[  1 578]
#  [  0 570]]
# -------------------
# Percentile: 2%
# Threshold: 0.000674
# Accuracy: 0.4996
# Confusion Matrix:
# [[  4 575]
#  [  0 570]]
# -------------------
# Percentile: 3%
# Threshold: 0.000771
# Accuracy: 0.5022
# Confusion Matrix:
# [[  7 572]
#  [  0 570]]
# -------------------
# Percentile: 4%
# Threshold: 0.000825
# Accuracy: 0.5048
# Confusion Matrix:
# [[ 10 569]
#  [  0 570]]
# -------------------
# Percentile: 5%
# Threshold: 0.000875
# Accuracy: 0.5065
# Confusion Matrix:
# [[ 12 567]
#  [  0 570]]
# -------------------
# Percentile: 6%
# Threshold: 0.000929
# Accuracy: 0.5091
# Confusion Matrix:
# [[ 15 564]
#  [  0 570]]
# -------------------
# Percentile: 7%
# Threshold: 0.000963
# Accuracy: 0.5091
# Confusion Matrix:
# [[ 15 564]
#  [  0 570]]
# -------------------
# Percentile: 8%
# Threshold: 0.000997
# Accuracy: 0.5100
# Confusion Matrix:
# [[ 16 563]
#  [  0 570]]
# -------------------
# Percentile: 9%
# Threshold: 0.001022
# Accuracy: 0.5109
# Confusion Matrix:
# [[ 17 562]
#  [  0 570]]
# -------------------
# Percentile: 10%
# Threshold: 0.001048
# Accuracy: 0.5126
# Confusion Matrix:
# [[ 20 559]
#  [  1 569]]
# -------------------
# Percentile: 11%
# Threshold: 0.001072
# Accuracy: 0.5135
# Confusion Matrix:
# [[ 21 558]
#  [  1 569]]
# -------------------
# Percentile: 12%
# Threshold: 0.001111
# Accuracy: 0.5144
# Confusion Matrix:
# [[ 22 557]
#  [  1 569]]
# -------------------
# Percentile: 13%
# Threshold: 0.001169
# Accuracy: 0.5187
# Confusion Matrix:
# [[ 27 552]
#  [  1 569]]
# -------------------
# Percentile: 14%
# Threshold: 0.001192
# Accuracy: 0.5196
# Confusion Matrix:
# [[ 28 551]
#  [  1 569]]
# -------------------
# Percentile: 15%
# Threshold: 0.001211
# Accuracy: 0.5213
# Confusion Matrix:
# [[ 30 549]
#  [  1 569]]
# -------------------
# Percentile: 16%
# Threshold: 0.001247
# Accuracy: 0.5257
# Confusion Matrix:
# [[ 35 544]
#  [  1 569]]
# -------------------
# Percentile: 17%
# Threshold: 0.001275
# Accuracy: 0.5274
# Confusion Matrix:
# [[ 37 542]
#  [  1 569]]
# -------------------
# Percentile: 18%
# Threshold: 0.001298
# Accuracy: 0.5309
# Confusion Matrix:
# [[ 41 538]
#  [  1 569]]
# -------------------
# Percentile: 19%
# Threshold: 0.001319
# Accuracy: 0.5335
# Confusion Matrix:
# [[ 44 535]
#  [  1 569]]
# -------------------
# Percentile: 20%
# Threshold: 0.001345
# Accuracy: 0.5335
# Confusion Matrix:
# [[ 44 535]
#  [  1 569]]
# -------------------
# Percentile: 21%
# Threshold: 0.001365
# Accuracy: 0.5335
# Confusion Matrix:
# [[ 44 535]
#  [  1 569]]
# -------------------
# Percentile: 22%
# Threshold: 0.001387
# Accuracy: 0.5344
# Confusion Matrix:
# [[ 45 534]
#  [  1 569]]
# -------------------
# Percentile: 23%
# Threshold: 0.001413
# Accuracy: 0.5396
# Confusion Matrix:
# [[ 51 528]
#  [  1 569]]
# -------------------
# Percentile: 24%
# Threshold: 0.001434
# Accuracy: 0.5422
# Confusion Matrix:
# [[ 54 525]
#  [  1 569]]
# -------------------
# Percentile: 25%
# Threshold: 0.001457
# Accuracy: 0.5448
# Confusion Matrix:
# [[ 57 522]
#  [  1 569]]
# -------------------
# Percentile: 26%
# Threshold: 0.001477
# Accuracy: 0.5492
# Confusion Matrix:
# [[ 62 517]
#  [  1 569]]
# -------------------
# Percentile: 27%
# Threshold: 0.001497
# Accuracy: 0.5527
# Confusion Matrix:
# [[ 66 513]
#  [  1 569]]
# -------------------
# Percentile: 28%
# Threshold: 0.001514
# Accuracy: 0.5535
# Confusion Matrix:
# [[ 67 512]
#  [  1 569]]
# -------------------
# Percentile: 29%
# Threshold: 0.001534
# Accuracy: 0.5544
# Confusion Matrix:
# [[ 68 511]
#  [  1 569]]
# -------------------
# Percentile: 30%
# Threshold: 0.001562
# Accuracy: 0.5570
# Confusion Matrix:
# [[ 71 508]
#  [  1 569]]
# -------------------
# Percentile: 31%
# Threshold: 0.001584
# Accuracy: 0.5579
# Confusion Matrix:
# [[ 72 507]
#  [  1 569]]
# -------------------
# Percentile: 32%
# Threshold: 0.001609
# Accuracy: 0.5605
# Confusion Matrix:
# [[ 75 504]
#  [  1 569]]
# -------------------
# Percentile: 33%
# Threshold: 0.001639
# Accuracy: 0.5648
# Confusion Matrix:
# [[ 80 499]
#  [  1 569]]
# -------------------
# Percentile: 34%
# Threshold: 0.001668
# Accuracy: 0.5674
# Confusion Matrix:
# [[ 83 496]
#  [  1 569]]
# -------------------
# Percentile: 35%
# Threshold: 0.001687
# Accuracy: 0.5692
# Confusion Matrix:
# [[ 85 494]
#  [  1 569]]
# -------------------
# Percentile: 36%
# Threshold: 0.001704
# Accuracy: 0.5718
# Confusion Matrix:
# [[ 88 491]
#  [  1 569]]
# -------------------
# Percentile: 37%
# Threshold: 0.001720
# Accuracy: 0.5727
# Confusion Matrix:
# [[ 90 489]
#  [  2 568]]
# -------------------
# Percentile: 38%
# Threshold: 0.001749
# Accuracy: 0.5735
# Confusion Matrix:
# [[ 91 488]
#  [  2 568]]
# -------------------
# Percentile: 39%
# Threshold: 0.001764
# Accuracy: 0.5753
# Confusion Matrix:
# [[ 93 486]
#  [  2 568]]
# -------------------
# Percentile: 40%
# Threshold: 0.001786
# Accuracy: 0.5770
# Confusion Matrix:
# [[ 96 483]
#  [  3 567]]
# -------------------
# Percentile: 41%
# Threshold: 0.001809
# Accuracy: 0.5805
# Confusion Matrix:
# [[100 479]
#  [  3 567]]
# -------------------
# Percentile: 42%
# Threshold: 0.001836
# Accuracy: 0.5849
# Confusion Matrix:
# [[106 473]
#  [  4 566]]
# -------------------
# Percentile: 43%
# Threshold: 0.001871
# Accuracy: 0.5936
# Confusion Matrix:
# [[116 463]
#  [  4 566]]
# -------------------
# Percentile: 44%
# Threshold: 0.001884
# Accuracy: 0.5953
# Confusion Matrix:
# [[118 461]
#  [  4 566]]
# -------------------
# Percentile: 45%
# Threshold: 0.001904
# Accuracy: 0.5970
# Confusion Matrix:
# [[120 459]
#  [  4 566]]
# -------------------
# Percentile: 46%
# Threshold: 0.001916
# Accuracy: 0.5979
# Confusion Matrix:
# [[121 458]
#  [  4 566]]
# -------------------
# Percentile: 47%
# Threshold: 0.001932
# Accuracy: 0.6023
# Confusion Matrix:
# [[126 453]
#  [  4 566]]
# -------------------
# Percentile: 48%
# Threshold: 0.001951
# Accuracy: 0.6066
# Confusion Matrix:
# [[132 447]
#  [  5 565]]
# -------------------
# Percentile: 49%
# Threshold: 0.001972
# Accuracy: 0.6101
# Confusion Matrix:
# [[137 442]
#  [  6 564]]
# -------------------
# Percentile: 50%
# Threshold: 0.001995
# Accuracy: 0.6136
# Confusion Matrix:
# [[141 438]
#  [  6 564]]
# -------------------
# Percentile: 51%
# Threshold: 0.002012
# Accuracy: 0.6171
# Confusion Matrix:
# [[145 434]
#  [  6 564]]
# -------------------
# Percentile: 52%
# Threshold: 0.002031
# Accuracy: 0.6214
# Confusion Matrix:
# [[150 429]
#  [  6 564]]
# -------------------
# Percentile: 53%
# Threshold: 0.002051
# Accuracy: 0.6214
# Confusion Matrix:
# [[151 428]
#  [  7 563]]
# -------------------
# Percentile: 54%
# Threshold: 0.002070
# Accuracy: 0.6258
# Confusion Matrix:
# [[156 423]
#  [  7 563]]
# -------------------
# Percentile: 55%
# Threshold: 0.002080
# Accuracy: 0.6292
# Confusion Matrix:
# [[160 419]
#  [  7 563]]
# -------------------
# Percentile: 56%
# Threshold: 0.002112
# Accuracy: 0.6336
# Confusion Matrix:
# [[166 413]
#  [  8 562]]
# -------------------
# Percentile: 57%
# Threshold: 0.002136
# Accuracy: 0.6388
# Confusion Matrix:
# [[172 407]
#  [  8 562]]
# -------------------
# Percentile: 58%
# Threshold: 0.002171
# Accuracy: 0.6432
# Confusion Matrix:
# [[178 401]
#  [  9 561]]
# -------------------
# Percentile: 59%
# Threshold: 0.002195
# Accuracy: 0.6466
# Confusion Matrix:
# [[182 397]
#  [  9 561]]
# -------------------
# Percentile: 60%
# Threshold: 0.002231
# Accuracy: 0.6571
# Confusion Matrix:
# [[195 384]
#  [ 10 560]]
# -------------------
# Percentile: 61%
# Threshold: 0.002249
# Accuracy: 0.6580
# Confusion Matrix:
# [[196 383]
#  [ 10 560]]
# -------------------
# Percentile: 62%
# Threshold: 0.002284
# Accuracy: 0.6641
# Confusion Matrix:
# [[205 374]
#  [ 12 558]]
# -------------------
# Percentile: 63%
# Threshold: 0.002302
# Accuracy: 0.6675
# Confusion Matrix:
# [[210 369]
#  [ 13 557]]
# -------------------
# Percentile: 64%
# Threshold: 0.002336
# Accuracy: 0.6710
# Confusion Matrix:
# [[216 363]
#  [ 15 555]]
# -------------------
# Percentile: 65%
# Threshold: 0.002352
# Accuracy: 0.6736
# Confusion Matrix:
# [[220 359]
#  [ 16 554]]
# -------------------
# Percentile: 66%
# Threshold: 0.002381
# Accuracy: 0.6832
# Confusion Matrix:
# [[232 347]
#  [ 17 553]]
# -------------------
# Percentile: 67%
# Threshold: 0.002405
# Accuracy: 0.6910
# Confusion Matrix:
# [[241 338]
#  [ 17 553]]
# -------------------
# Percentile: 68%
# Threshold: 0.002416
# Accuracy: 0.6919
# Confusion Matrix:
# [[242 337]
#  [ 17 553]]
# -------------------
# Percentile: 69%
# Threshold: 0.002433
# Accuracy: 0.6945
# Confusion Matrix:
# [[245 334]
#  [ 17 553]]
# -------------------
# Percentile: 70%
# Threshold: 0.002477
# Accuracy: 0.7058
# Confusion Matrix:
# [[260 319]
#  [ 19 551]]
# -------------------
# Percentile: 71%
# Threshold: 0.002498
# Accuracy: 0.7058
# Confusion Matrix:
# [[261 318]
#  [ 20 550]]
# -------------------
# Percentile: 72%
# Threshold: 0.002514
# Accuracy: 0.7058
# Confusion Matrix:
# [[261 318]
#  [ 20 550]]
# -------------------
# Percentile: 73%
# Threshold: 0.002557
# Accuracy: 0.7180
# Confusion Matrix:
# [[277 302]
#  [ 22 548]]
# -------------------
# Percentile: 74%
# Threshold: 0.002591
# Accuracy: 0.7258
# Confusion Matrix:
# [[289 290]
#  [ 25 545]]
# -------------------
# Percentile: 75%
# Threshold: 0.002618
# Accuracy: 0.7285
# Confusion Matrix:
# [[294 285]
#  [ 27 543]]
# -------------------
# Percentile: 76%
# Threshold: 0.002660
# Accuracy: 0.7328
# Confusion Matrix:
# [[300 279]
#  [ 28 542]]
# -------------------
# Percentile: 77%
# Threshold: 0.002703
# Accuracy: 0.7302
# Confusion Matrix:
# [[302 277]
#  [ 33 537]]
# -------------------
# Percentile: 78%
# Threshold: 0.002746
# Accuracy: 0.7346
# Confusion Matrix:
# [[311 268]
#  [ 37 533]]
# -------------------
# Percentile: 79%
# Threshold: 0.002788
# Accuracy: 0.7398
# Confusion Matrix:
# [[319 260]
#  [ 39 531]]
# -------------------
# Percentile: 80%
# Threshold: 0.002825
# Accuracy: 0.7459
# Confusion Matrix:
# [[326 253]
#  [ 39 531]]
# -------------------
# Percentile: 81%
# Threshold: 0.002867
# Accuracy: 0.7520
# Confusion Matrix:
# [[335 244]
#  [ 41 529]]
# -------------------
# Percentile: 82%
# Threshold: 0.002903
# Accuracy: 0.7572
# Confusion Matrix:
# [[342 237]
#  [ 42 528]]
# -------------------
# Percentile: 83%
# Threshold: 0.002949
# Accuracy: 0.7607
# Confusion Matrix:
# [[347 232]
#  [ 43 527]]
# -------------------
# Percentile: 84%
# Threshold: 0.003029
# Accuracy: 0.7624
# Confusion Matrix:
# [[358 221]
#  [ 52 518]]
# -------------------
# Percentile: 85%
# Threshold: 0.003060
# Accuracy: 0.7624
# Confusion Matrix:
# [[361 218]
#  [ 55 515]]
# -------------------
# Percentile: 86%
# Threshold: 0.003130
# Accuracy: 0.7641
# Confusion Matrix:
# [[369 210]
#  [ 61 509]]
# -------------------
# Percentile: 87%
# Threshold: 0.003193
# Accuracy: 0.7685
# Confusion Matrix:
# [[377 202]
#  [ 64 506]]
# -------------------
# Percentile: 88%
# Threshold: 0.003261
# Accuracy: 0.7702
# Confusion Matrix:
# [[383 196]
#  [ 68 502]]
# -------------------
# Percentile: 89%
# Threshold: 0.003371
# Accuracy: 0.7842
# Confusion Matrix:
# [[403 176]
#  [ 72 498]]
# -------------------
# Percentile: 90%
# Threshold: 0.003482
# Accuracy: 0.7876
# Confusion Matrix:
# [[424 155]
#  [ 89 481]]
# -------------------
# Percentile: 91%
# Threshold: 0.003573
# Accuracy: 0.7929
# Confusion Matrix:
# [[434 145]
#  [ 93 477]]
# -------------------
# Percentile: 92%
# Threshold: 0.003661
# Accuracy: 0.7955
# Confusion Matrix:
# [[444 135]
#  [100 470]]
# -------------------
# Percentile: 93%
# Threshold: 0.003862
# Accuracy: 0.7937
# Confusion Matrix:
# [[454 125]
#  [112 458]]
# -------------------
# Percentile: 94%
# Threshold: 0.004115
# Accuracy: 0.7903
# Confusion Matrix:
# [[475 104]
#  [137 433]]
# -------------------
# Percentile: 95%
# Threshold: 0.004300
# Accuracy: 0.7894
# Confusion Matrix:
# [[487  92]
#  [150 420]]
# -------------------
# Percentile: 96%
# Threshold: 0.004623
# Accuracy: 0.7876
# Confusion Matrix:
# [[511  68]
#  [176 394]]
# -------------------
# Percentile: 97%
# Threshold: 0.004917
# Accuracy: 0.7824
# Confusion Matrix:
# [[527  52]
#  [198 372]]
# -------------------
# Percentile: 98%
# Threshold: 0.005752
# Accuracy: 0.7293
# Confusion Matrix:
# [[552  27]
#  [284 286]]
# -------------------
# Percentile: 99%
# Threshold: 0.006466
# Accuracy: 0.6849
# Confusion Matrix:
# [[563  16]
#  [346 224]]
# -------------------
# Percentile: 100%
# Threshold: 0.013164
# Accuracy: 0.5117
# Confusion Matrix:
# [[579   0]
#  [561   9]]
# -------------------
#
# === Best Result ===
# Best Percentile: 92%
# Threshold: 0.003661
# Accuracy: 0.7955
# Confusion Matrix:
# [[444 135]
#  [100 470]]

# %%
# Plot 2: Percentile vs Accuracy
percentiles = list(results.keys())  # [1, 2, ..., 100]
accuracies = [results[p]['accuracy'] for p in results]

plt.figure(figsize=(10, 6))
plt.plot(percentiles, accuracies, marker='o', linestyle='-', color='g')
plt.title('Percentile vs Accuracy')
plt.xlabel('Percentile (%)')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
# Visualize predictions for the best result (15 images)
best_predictions = results[best_percentile]['predictions']
num_images_to_show = 15
indices = np.random.choice(len(test_images), num_images_to_show, replace=False)  # Randomly select 15 indices

plt.figure(figsize=(15, 9))
for i, idx in enumerate(indices):
    plt.subplot(3, 5, i + 1)  # 3 rows, 5 columns
    plt.imshow(test_images[idx].reshape(128, 128), cmap='gray')
    plt.title(f"True: {int(test_labels[idx])}\nPred: {best_predictions[idx]}")
    plt.axis('off')
plt.tight_layout()
plt.suptitle(f"Predictions for Best Threshold (Percentile: {best_percentile}%, Accuracy: {best_accuracy:.4f})", y=1.05)
plt.show()
